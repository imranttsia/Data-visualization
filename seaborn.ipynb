# %% [markdown]
# <a href="https://colab.research.google.com/github/imranttsia/Data-visualization/blob/main/seaborn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns

# %%
# Import seaborn
import seaborn as sns

# Apply the default theme
sns.set_theme()

# Load an example dataset
tips = sns.load_dataset("tips")
# tips
# Create a visualization
#sns.relplot(
#     data=tips,
  #  x="total_bill", y="tip" , col="time",
   # hue="smoker",
    #style="smoker",
    #size="size",
#)

# %%
# Import seaborn
import seaborn as sns

# Apply the default theme
sns.set_theme()

# Load an example dataset
tips = sns.load_dataset("tips")
# tips
# Create a visualization
sns.relplot(
     data=tips,
     x="total_bill", y="tip" , col="time",)
   # hue="smoker",
    #style="smoker",
    #size="size",
#)

# %%
# Import seaborn
import seaborn as sns

# Apply the default theme
sns.set_theme()

# Load an example dataset
tips = sns.load_dataset("tips")
# tips
# Create a visualization
sns.relplot(
     data=tips,
     x="total_bill", y="tip" , col="time",
     hue="smoker", )
    #style="smoker",
    #size="size",
#)

# %%
# Import seaborn
import seaborn as sns

# Apply the default theme
sns.set_theme()

# Load an example dataset
tips = sns.load_dataset("tips")
# tips
# Create a visualization
sns.relplot(
     data=tips,
     x="total_bill", y="tip" , col="time",
     hue="smoker",
     style="smoker", )
    #size="size",
#)

# %%
# Import seaborn
import seaborn as sns

# Apply the default theme
sns.set_theme()

# Load an example dataset
tips = sns.load_dataset("tips")
# tips
# Create a visualization
sns.relplot(
     data=tips,
     x="total_bill", y="tip" , col="time",
     hue="smoker",
     style="smoker",
     size="size",
)

# %%
tips = sns.load_dataset("tips")
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
tips.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
tips.sex.unique
# Out:
# <bound method Series.unique of 0      Female
# 1        Male
# 2        Male
# 3        Male
# 4      Female
#         ...
# 239      Male
# 240    Female
# 241      Male
# 242      Male
# 243    Female
# Name: sex, Length: 244, dtype: category
# Categories (2, object): ['Male', 'Female']>

# %%
sns.lmplot(data=tips, x="total_bill", y="tip", col="time", hue="smoker")

# %%
sns.displot(data=tips, x="total_bill", col="time", kde=True)

# %%
sns.catplot(data=tips, kind="swarm", x="day", y="total_bill", hue="smoker")

# %%
sns.catplot(data=tips, kind="violin", x="day", y="total_bill", hue="smoker", split=True)

# %%
sns.catplot(data=tips, kind="bar", x="day", y="total_bill", hue="smoker")

# %%
for c in tips.columns:
  display(tips[c].value_counts().head())
# Out:
# 13.42    3
# 13.81    2
# 15.98    2
# 17.92    2
# 10.07    2
# Name: total_bill, dtype: int64
# 2.0    33
# 3.0    23
# 4.0    12
# 5.0    10
# 2.5    10
# Name: tip, dtype: int64
# Male      157
# Female     87
# Name: sex, dtype: int64
# No     151
# Yes     93
# Name: smoker, dtype: int64
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: day, dtype: int64
# Dinner    176
# Lunch      68
# Name: time, dtype: int64
# 2    156
# 3     38
# 4     37
# 5      5
# 1      4
# Name: size, dtype: int64

# %%
print(len(tips))
# Out:
# 244

# %%
tips.time.value_counts()
# Out:
# Dinner    176
# Lunch      68
# Name: time, dtype: int64

# %%
tips.smoker.value_counts()
# Out:
# No     151
# Yes     93
# Name: smoker, dtype: int64

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
penguins = sns.load_dataset("penguins")
sns.jointplot(data=penguins, x="flipper_length_mm", y="bill_length_mm", hue="species")

# %%
sns.pairplot(data=penguins, hue="species")

# %%
penguins
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
dots = sns.load_dataset("dots")
sns.relplot(
    data=dots, kind="line",
    x="time", y="firing_rate"
    # , col="align",
    # hue="choice", size="coherence",
    # style="choice",
    # facet_kws=dict(sharex=False),
)

# %%
dots = sns.load_dataset("dots")
sns.relplot(
    data=dots, kind="line",
    x="time", y="firing_rate"
    , col="align",
    # hue="choice", size="coherence",
    # style="choice",
    # facet_kws=dict(sharex=False),
)

# %%
dots = sns.load_dataset("dots")
sns.relplot(
    data=dots, kind="line",
    x="time", y="firing_rate"
    , col="align",
    hue="choice", size="coherence",
    # style="choice",
    # facet_kws=dict(sharex=False),
)

# %%
dots = sns.load_dataset("dots")
sns.relplot(
    data=dots, kind="line",
    x="time", y="firing_rate"
    , col="align",
    hue="choice", size="coherence",
    style="choice",
    # facet_kws=dict(sharex=False),
)

# %%
dots = sns.load_dataset("dots")
sns.relplot(
    data=dots, kind="line",
    x="time", y="firing_rate"
    , col="align",
    hue="choice", size="coherence",
    style="choice",
    facet_kws=dict(sharex=False),
)

# %%
dots.head()
# Out:
#   align choice  time  coherence  firing_rate
# 0  dots     T1   -80        0.0    33.189967
# 1  dots     T1   -80        3.2    31.691726
# 2  dots     T1   -80        6.4    34.279840
# 3  dots     T1   -80       12.8    32.631874
# 4  dots     T1   -80       25.6    35.060487

# %%
for c in dots.columns:
    display(dots[c].value_counts().head(10))
# Out:
# sacc    454
# dots    394
# Name: align, dtype: int64
# T2    430
# T1    418
# Name: choice, dtype: int64
# -80     24
#  120    24
#  280    24
#  260    24
#  240    24
#  220    24
#  200    24
#  180    24
#  160    24
# -60     24
# Name: time, dtype: int64
# 0.0     174
# 3.2     170
# 6.4     156
# 12.8    142
# 25.6    116
# 51.2     90
# Name: coherence, dtype: int64
# 33.281734    2
# 29.696673    2
# 29.643963    2
# 28.675048    2
# 32.366071    2
# 28.384913    2
# 29.844961    2
# 35.648148    2
# 29.166667    2
# 34.984520    2
# Name: firing_rate, dtype: int64

# %%
fmri = sns.load_dataset("fmri")
sns.relplot(
    data=fmri, kind="line",
    # x="timepoint", y="signal", col="region",
    # hue="event", style="event",
)

# %%
fmri = sns.load_dataset("fmri")
sns.relplot(
    data=fmri, kind="line",
    x="timepoint", y="signal",
    # col="region",
    # hue="event", style="event",
)

# %%
fmri = sns.load_dataset("fmri")
sns.relplot(
    data=fmri, kind="line",
    x="timepoint", y="signal", col="region",
    # hue="event", style="event",
)

# %%
fmri = sns.load_dataset("fmri")
sns.relplot(
    data=fmri, kind="line",
    x="timepoint", y="signal", col="region",
    hue="event",
    # style="event",
)

# %%
fmri = sns.load_dataset("fmri")
sns.relplot(
    data=fmri, kind="line",
    x="timepoint", y="signal", col="region",
    hue="event", style="event",
)

# %%
for c in fmri.columns:
    display(fmri[c].value_counts().head(10))
# Out:
# s13    76
# s5     76
# s12    76
# s11    76
# s10    76
# s9     76
# s8     76
# s7     76
# s6     76
# s4     76
# Name: subject, dtype: int64
# 18    56
# 10    56
# 4     56
# 5     56
# 6     56
# 2     56
# 8     56
# 7     56
# 3     56
# 11    56
# Name: timepoint, dtype: int64
# stim    532
# cue     532
# Name: event, dtype: int64
# parietal    532
# frontal     532
# Name: region, dtype: int64
# -0.017552    1
# -0.037439    1
# -0.025904    1
# -0.043021    1
#  0.004315    1
# -0.045956    1
# -0.021160    1
#  0.006142    1
# -0.057706    1
# -0.040937    1
# Name: signal, dtype: int64

# %%
fmri
# Out:
#      subject  timepoint event    region    signal
# 0        s13         18  stim  parietal -0.017552
# 1         s5         14  stim  parietal -0.080883
# 2        s12         18  stim  parietal -0.081033
# 3        s11         18  stim  parietal -0.046134
# 4        s10         18  stim  parietal -0.037970
# ...      ...        ...   ...       ...       ...
# 1059      s0          8   cue   frontal  0.018165
# 1060     s13          7   cue   frontal -0.029130
# 1061     s12          7   cue   frontal -0.004939
# 1062     s11          7   cue   frontal -0.025367
# 1063      s0          0   cue  parietal -0.006899
#
# [1064 rows x 5 columns]
