# %% [markdown]
# <a href="https://colab.research.google.com/github/imranttsia/Data-visualization/blob/main/Beautiful_soup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# numpy 2.1.0
#
# first digit = platform and architecture
#
# second digit = when we add new feature or remove feature
#
# third digit = when we fix any bugs or small change

# %%
print "Pakistan zinda bad"
# Out:
#   File "<ipython-input-1-029b54432c9f>", line 1
#     print "Pakistan zinda bad"
#     ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?

# %%
print("Pakistan zinda bad")

# %%
# !pip install beautifulsoup4

# %%
raw_text = """
<html><head><title>The Dormouse's story</title></head>
<body>
<p class="title"><b>The Dormouse's story</b></p>

<p class="story">Once upon a time there were three little sisters; and their names were
<a href="http://example.com/elsie" class="sister" id="link1">Elsie</a>,
<a href="http://example.com/lacie" class="sister" id="link2">Lacie</a> and
<a href="http://example.com/tillie" class="sister" id="link3">Tillie</a>;
and they lived at the bottom of a well.</p>

<p class="story">Pakistan</p>

"""

print(type(raw_text))
# Out:
# <class 'str'>

# %%
import re
re.findall("<p.*?>", raw_text)
# Out:
# ['<p class="title">', '<p class="story">', '<p class="story">']

# %% [markdown]
# Now apply beautiful soup package

# %%
raw_text
# Out:
# '\n<html><head><title>The Dormouse\'s story</title></head>\n<body>\n<p class="title"><b>The Dormouse\'s story</b></p>\n\n<p class="story">Once upon a time there were three little sisters; and their names were\n<a href="http://example.com/elsie" class="sister" id="link1">Elsie</a>,\n<a href="http://example.com/lacie" class="sister" id="link2">Lacie</a> and\n<a href="http://example.com/tillie" class="sister" id="link3">Tillie</a>;\nand they lived at the bottom of a well.</p>\n\n<p class="story">Pakistan</p>\n\n'

# %%
from bs4 import BeautifulSoup

html = BeautifulSoup(raw_text,'html.parser')

print(type(html))
print(type(raw_text))
# Out:
# <class 'bs4.BeautifulSoup'>
# <class 'str'>

# %%
print(html.prettify())
# Out:
# <html>
#  <head>
#   <title>
#    The Dormouse's story
#   </title>
#  </head>
#  <body>
#   <p class="title">
#    <b>
#     The Dormouse's story
#    </b>
#   </p>
#   <p class="story">
#    Once upon a time there were three little sisters; and their names were
#    <a class="sister" href="http://example.com/elsie" id="link1">
#     Elsie
#    </a>
#    ,
#    <a class="sister" href="http://example.com/lacie" id="link2">
#     Lacie
#    </a>
#    and
#    <a class="sister" href="http://example.com/tillie" id="link3">
#     Tillie
#    </a>
#    ;
# and they lived at the bottom of a well.
#   </p>
#   <p class="story">
#    Pakistan
#   </p>
#  </body>
# </html>

# %%
html.find_all("p")
# Out:
# [<p class="title"><b>The Dormouse's story</b></p>,
#  <p class="story">Once upon a time there were three little sisters; and their names were
#  <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
#  <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a> and
#  <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>;
#  and they lived at the bottom of a well.</p>,
#  <p class="story">Pakistan</p>]

# %%
p = html.find_all("p")
print(len(p))
p
# Out:
# 3
# [<p class="title"><b>The Dormouse's story</b></p>,
#  <p class="story">Once upon a time there were three little sisters; and their names were
#  <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
#  <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a> and
#  <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>;
#  and they lived at the bottom of a well.</p>,
#  <p class="story">Pakistan</p>]

# %%
for tag in p:
    print(tag.text)
    print("=========")
# Out:
# The Dormouse's story
# ...
# Once upon a time there were three little sisters; and their names were
# Elsie,
# Lacie and
# Tillie;
# and they lived at the bottom of a well.
# ...
# Pakistan
# ...

# %%
for tag in p:
    print(tag.name, "===",tag.text)
    print("=========")
# Out:
# p === The Dormouse's story
# ...
# p === Once upon a time there were three little sisters; and their names were
# Elsie,
# Lacie and
# Tillie;
# and they lived at the bottom of a well.
# ...
# p === Pakistan
# ...

# %%
print(html.prettify())
# Out:
# <html>
#  <head>
#   <title>
#    The Dormouse's story
#   </title>
#  </head>
#  <body>
#   <p class="title">
#    <b>
#     The Dormouse's story
#    </b>
#   </p>
#   <p class="story">
#    Once upon a time there were three little sisters; and their names were
#    <a class="sister" href="http://example.com/elsie" id="link1">
#     Elsie
#    </a>
#    ,
#    <a class="sister" href="http://example.com/lacie" id="link2">
#     Lacie
#    </a>
#    and
#    <a class="sister" href="http://example.com/tillie" id="link3">
#     Tillie
#    </a>
#    ;
# and they lived at the bottom of a well.
#   </p>
#   <p class="story">
#    Pakistan
#   </p>
#  </body>
# </html>

# %%
html.title
# Out:
# <title>The Dormouse's story</title>

# %%
html.p
# Out:
# <p class="title"><b>The Dormouse's story</b></p>

# %%
html.a
# Out:
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>

# %%
html.title.name
# Out:
# 'title'

# %%
html.title.text
# Out:
# "The Dormouse's story"

# %%
html.title.parent
# Out:
# <head><title>The Dormouse's story</title></head>

# %%
html.title.parent.name
# Out:
# 'head'

# %%
print(html.p)
html.p['class']
# Out:
# <p class="title"><b>The Dormouse's story</b></p>
# ['title']

# %%
html.a
# Out:
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>

# %%
print(html.a['href'])
print(html.a['class'])
# Out:
# http://example.com/elsie
# ['sister']

# %%
html.a
# Out:
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>

# %%
html.find_all("a")
# Out:
# [<a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
#  <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>,
#  <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>]

# %%
l1 = html.find_all("a")
for tag in l1:
    print(tag.name,tag.text)
# Out:
# a Elsie
# a Lacie
# a Tillie

# %%
l1 = html.find_all("a")
for tag in l1:
    print(tag.name,tag.text,tag['href'])
# Out:
# a Elsie http://example.com/elsie
# a Lacie http://example.com/lacie
# a Tillie http://example.com/tillie

# %%
l1 = html.find_all("a")
for tag in l1:
    print(tag.name,tag.text,tag['href'], tag['id'], tag['class'])
# Out:
# a Elsie http://example.com/elsie link1 ['sister']
# a Lacie http://example.com/lacie link2 ['sister']
# a Tillie http://example.com/tillie link3 ['sister']

# %%
import pandas as pd

# %%
l1 = html.find_all("a")
df_l = []
for tag in l1:
#     print(tag.name,tag.text,tag['href'], tag['id'], tag['class'])
    df_l.append([tag.name,tag.text,tag['href'], tag['id'], tag['class']])


df_l
# Out:
# [['a', 'Elsie', 'http://example.com/elsie', 'link1', ['sister']],
#  ['a', 'Lacie', 'http://example.com/lacie', 'link2', ['sister']],
#  ['a', 'Tillie', 'http://example.com/tillie', 'link3', ['sister']]]

# %%
df = pd.DataFrame(df_l,
                 columns=["Tag","Text","Links","ids",'class'])
df
# Out:
#   Tag    Text                      Links    ids     class
# 0   a   Elsie   http://example.com/elsie  link1  [sister]
# 1   a   Lacie   http://example.com/lacie  link2  [sister]
# 2   a  Tillie  http://example.com/tillie  link3  [sister]

# %% [markdown]
# Now Extract hmlt information from live websit

# %%
import urllib.request   # not urllib - important!
url_text = urllib.request.urlopen('https://www.w3schools.com/')
print(type(url_text))
# Out:
# <class 'http.client.HTTPResponse'>

# %%
from bs4 import BeautifulSoup
live_web = BeautifulSoup(url_text,'html.parser')
print(live_web.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en-US">
#  <head>
#   <title>
#    W3Schools Online Web Tutorials
#   </title>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <meta content="HTML, Python, CSS, SQL, JavaScript, How to, PHP, Java, C, C++, C#, jQuery, Bootstrap, Colors, W3.CSS, XML, MySQL, Icons, NodeJS, React, Graphics, Angular, R, AI, Git, Data Science, Code Game, Tutorials, Programming, Web Development, Training, Learning, Quiz, Exercises, Courses, Lessons, References, Examples, Learn to code, Source code, Demos, Tips, Website" name="Keywords"/>
#   <meta content="Well organized and easy to understand Web building tutorials with lots of examples of how to use HTML, CSS, JavaScript, SQL, Python, PHP, Bootstrap, Java, XML and more." name="Description"/>
#   <meta content="https://www.w3schools.com/images/w3schools_logo_436_2.png" property="og:image"/>
#   <meta content="image/png" property="og:image:type"/>
# ...

# %%
l1 = live_web.find_all("a")
print(len(l1))
# Out:
# 652

# %%
df_l = []
for tag in l1:
    df_l.append([tag.text,tag['href']])

df = pd.DataFrame(df_l, columns = ['text','links'])
print(len(df))
df
# Out:
# 652
#                                text                                  links
# 0                              \n\n             https://www.w3schools.com
# 1                        Tutorials                      javascript:void(0)
# 2                        Exercises                      javascript:void(0)
# 3                    Get Certified                      javascript:void(0)
# 4                         Services                      javascript:void(0)
# ..                              ...                                    ...
# 647                    terms of use             /about/about_copyright.asp
# 648       cookie and privacy policy               /about/about_privacy.asp
# 649             Copyright 1999-2023             /about/about_copyright.asp
# 650  W3Schools is Powered by W3.CSS  //www.w3schools.com/w3css/default.asp
# 651                            \n\n                    //www.w3schools.com
#
# [652 rows x 2 columns]

# %%
df = df.drop_duplicates()
print(len(df))
# Out:
# 532

# %%
df.head()
# Out:
#              text                       links
# 0            \n\n  https://www.w3schools.com
# 1      Tutorials           javascript:void(0)
# 2      Exercises           javascript:void(0)
# 3  Get Certified           javascript:void(0)
# 4       Services           javascript:void(0)

# %%
a = df.drop_duplicates("links")
print(len(a))
a.head()
# Out:
# 264
#          text                                              links
# 0        \n\n                         https://www.w3schools.com
# 1  Tutorials                                  javascript:void(0)
# 6      Log in  https://profile.w3schools.com/log-in?redirect_...
# 7     Upgrade  https://billing.w3schools.com/products/spaces?...
# 8     Sign Up                                  /signup/index.php

# %%
a = df.drop_duplicates("text")
print(len(a))
a.head()
# Out:
# 295
#              text                       links
# 0            \n\n  https://www.w3schools.com
# 1      Tutorials           javascript:void(0)
# 2      Exercises           javascript:void(0)
# 3  Get Certified           javascript:void(0)
# 4       Services           javascript:void(0)

# %%
import urllib.request   # not urllib - important!
url_text1 = urllib.request.urlopen('https://www.linkedin.com/feed/')
print(type(url_text1))
from bs4 import BeautifulSoup
live_web1 = BeautifulSoup(url_text1,'html.parser')
print(live_web1.prettify())
# Out:
# <class 'http.client.HTTPResponse'>
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta content="d_registration-cold-join" name="pageKey"/>
#   <meta content="en_US" name="locale"/>
#   <meta data-app-id="com.linkedin.registration-frontend.d_web" data-app-version="" data-custom-tracking-code="" data-disable-comscore-tracking="" data-enable-page-view-heartbeat-tracking="" data-jet-tags="" data-multiproduct-name="registration-fe" data-service-name="registration-frontend" data-tracking-page-type="" id="config">
#    <link href="https://www.linkedin.com/signup" rel="canonical"/>
#    <link href="https://www.linkedin.com/signup?_l=no" hreflang="no" rel="alternate">
#     <link href="https://www.linkedin.com/signup?_l=de" hreflang="de" rel="alternate"/>
#     <link href="https://www.linkedin.com/signup?_l=sv" hreflang="sv" rel="alternate"/>
#     <link href="https://www.linkedin.com/signup?_l=ru" hreflang="ru" rel="alternate"/>
# ...

# %%
l2 = live_web1.find_all("a")
print(len(l2))
# Out:
# 15

# %%
df_2 = []
for tag in l2:
    df_2.append([tag.text,tag['href']])

df2 = pd.DataFrame(df_2, columns = ['text','links'])
print(len(df2))
df2
# Out:
# 15
#                                text  \
# 0                    User Agreement
# 1                    Privacy Policy
# 2                     Cookie Policy
# 3                           Sign in
# 4                          Get help
# 5                             About
# 6                     Accessibility
# 7                    User Agreement
# 8                    Privacy Policy
# 9   Your California Privacy Choices
# 10                    Cookie Policy
# 11                 Copyright Policy
# 12                     Brand Policy
# 13                   Guest Controls
# 14             Community Guidelines
#
#                                                 links
# 0   https://www.linkedin.com/legal/user-agreement?...
# 1   https://www.linkedin.com/legal/privacy-policy?...
# 2   https://www.linkedin.com/legal/cookie-policy?s...
# 3   https://www.linkedin.com/uas/login?session_red...
# 4   https://www.linkedin.com/help/linkedin/answer/...
# ...

# %%
df2.head()
# Out:
#              text                                              links
# 0  User Agreement  https://www.linkedin.com/legal/user-agreement?...
# 1  Privacy Policy  https://www.linkedin.com/legal/privacy-policy?...
# 2   Cookie Policy  https://www.linkedin.com/legal/cookie-policy?s...
# 3         Sign in  https://www.linkedin.com/uas/login?session_red...
# 4        Get help  https://www.linkedin.com/help/linkedin/answer/...
